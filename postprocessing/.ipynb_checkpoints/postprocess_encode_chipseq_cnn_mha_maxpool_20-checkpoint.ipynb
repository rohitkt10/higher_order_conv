# %%
import numpy as np
import h5py
import os, sys 
import pandas as pd 

from paramiko import SSHClient
from scp import SCPClient

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline

# %%
# set up local results directory
EXPT_DIRNAME = "cnn_att_encode_chipseq"
RESULTSDIR = os.path.join(os.getcwd(), '..', 'results', EXPT_DIRNAME)  ## local path
if not os.path.exists(RESULTSDIR):
    os.makedirs(RESULTSDIR)

# set up remote paths and ssh clients 
username, hostname = os.getenv('BAMDEV1').split("@")
ssh = SSHClient()
ssh.load_system_host_keys()
ssh.connect(hostname=hostname, username=username)
remotehome = ssh.exec_command("echo $HOME")[1].readlines()[0].strip()
scp = SCPClient(ssh.get_transport())
REMOTEDIR = os.path.join(remotehome, "projects/higher_order_convolutions_full/results", EXPT_DIRNAME)

# %%
# get all remote directories 
tfids = [l.strip() for l in ssh.exec_command("ls %s"%REMOTEDIR)[1].readlines()]
_remove = []
for tfid in tfids:
    if len(ssh.exec_command("find %s -name \"test_metrics.csv\""%os.path.join(REMOTEDIR, tfid))[1].readlines()) < 13:
        _remove.append(tfid)
tfids = [tfid for tfid in tfids if tfid not in _remove]
print(len(tfids))
# Out:
# 108

# %%
download = True
if download:
    for tfid in tfids:
        print("Downloading results for TF : %s"%tfid)
        remote_tfid_dir = os.path.join(REMOTEDIR, tfid)
        local_tfid_dir = os.path.join(RESULTSDIR, tfid)
        conv_type_dirs = [l.strip() for l in ssh.exec_command("ls %s"%remote_tfid_dir)[1].readlines()]

        for conv_type in conv_type_dirs:
            conv_type_dir = os.path.join(remote_tfid_dir, conv_type)
            res = [l.strip() for l in ssh.exec_command("ls %s"%conv_type_dir)[1].readlines()]

            # check for standard conv
            if "test_metrics.csv" in res:
                remote_path = os.path.join(conv_type_dir, "test_metrics.csv")
                local_path = os.path.join(local_tfid_dir, conv_type)
                if not os.path.exists(local_path):
                    os.makedirs(local_path)
                if not os.path.exists(os.path.join(local_path, "test_metrics.csv")):
                    scp.get(remote_path=remote_path, local_path=local_path)

                remote_path = os.path.join(conv_type_dir, "history.csv")
                local_path = os.path.join(local_tfid_dir, conv_type)
                if not os.path.exists(os.path.join(local_path, "history.csv")):
                    scp.get(remote_path=remote_path, local_path=local_path)

            else:
                for l1_dir in res:
                    remote_path = os.path.join(conv_type_dir, l1_dir, "test_metrics.csv")
                    local_path = os.path.join(local_tfid_dir, conv_type, l1_dir)
                    if not os.path.exists(local_path):
                        os.makedirs(local_path)
                    if not os.path.exists(os.path.join(local_path, "test_metrics.csv")):
                        scp.get(remote_path=remote_path, local_path=local_path)

                    remote_path = os.path.join(conv_type_dir, l1_dir, "history.csv")
                    local_path = os.path.join(local_tfid_dir, conv_type, l1_dir)
                    if not os.path.exists(os.path.join(local_path, "history.csv")):
                        scp.get(remote_path=remote_path, local_path=local_path)
# Out:
# Downloading results for TF : ARID3A_K562_ARID3A_-sc-8821-_Stanford
# Downloading results for TF : ATF1_K562_ATF1_-06-325-_Harvard
# Downloading results for TF : ATF3_K562_ATF3_HudsonAlpha
# Downloading results for TF : BACH1_K562_Bach1_-sc-14700-_Stanford
# Downloading results for TF : BCL3_K562_BCL3_HudsonAlpha
# Downloading results for TF : BCLAF1_K562_BCLAF1_-SC-101388-_HudsonAlpha
# Downloading results for TF : BDP1_K562_BDP1_Harvard
# Downloading results for TF : BHLHE40_K562_BHLHE40_-NB100-1800-_Stanford
# Downloading results for TF : CBX3_K562_CBX3_-SC-101004-_HudsonAlpha
# Downloading results for TF : CCNT2_K562_CCNT2_Harvard
# Downloading results for TF : CEBPB_K562_CEBPB_-SC-150-_HudsonAlpha
# Downloading results for TF : CEBPB_K562_CEBPB_Stanford
# Downloading results for TF : CHD1_K562_CHD1_-A301-218A-_Broad
# Downloading results for TF : CHD2_K562_CHD2_-AB68301-_Stanford
# Downloading results for TF : CTCF_K562_CTCF_Broad
# Downloading results for TF : CTCF_K562_CTCF_-SC-15914-_Stanford
# Downloading results for TF : CTCF_K562_CTCF_-SC-5916-_HudsonAlpha
# Downloading results for TF : CTCF_K562_CTCF_UT-A
# Downloading results for TF : CTCF_K562_CTCF_UW
# Downloading results for TF : CTCFL_K562_CTCFL_-SC-98982-_HudsonAlpha
# Downloading results for TF : E2F4_K562_E2F4_USC
# Downloading results for TF : E2F6_K562_E2F6_HudsonAlpha
# Downloading results for TF : E2F6_K562_E2F6_USC
# Downloading results for TF : EGR1_K562_Egr-1_HudsonAlpha
# Downloading results for TF : ELF1_K562_ELF1_-SC-631-_HudsonAlpha
# Downloading results for TF : EP300_K562_p300_Stanford
# Downloading results for TF : ETS1_K562_ETS1_HudsonAlpha
# Downloading results for TF : FOS_K562_c-Fos_Yale
# Downloading results for TF : FOS_K562_eGFP-FOS_UChicago
# Downloading results for TF : FOSL1_K562_FOSL1_-SC-183-_HudsonAlpha
# Downloading results for TF : GABPA_K562_GABP_HudsonAlpha
# Downloading results for TF : GATA1_K562_GATA-1_USC
# Downloading results for TF : GATA2_K562_eGFP-GATA2_UChicago
# Downloading results for TF : GATA2_K562_GATA2_-SC-267-_HudsonAlpha
# Downloading results for TF : GATA2_K562_GATA-2_USC
# Downloading results for TF : GTF2B_K562_GTF2B_Harvard
# Downloading results for TF : HDAC1_K562_HDAC1_-SC-6298-_Broad
# Downloading results for TF : HDAC2_K562_HDAC2_-A300-705A-_Broad
# Downloading results for TF : HDAC2_K562_HDAC2_-SC-6296-_HudsonAlpha
# Downloading results for TF : HDAC6_K562_HDAC6_-A301-341A-_Broad
# Downloading results for TF : HMGN3_K562_HMGN3_Harvard
# Downloading results for TF : JUNB_K562_eGFP-JunB_UChicago
# Downloading results for TF : JUND_K562_eGFP-JunD_UChicago
# Downloading results for TF : JUND_K562_JunD_Stanford
# Downloading results for TF : JUN_K562_c-Jun_Yale
# Downloading results for TF : KAP1_K562_KAP1_USC
# Downloading results for TF : KDM5B_K562_PLU1_Broad
# Downloading results for TF : MAFF_K562_MafF_-M8194-_Stanford
# Downloading results for TF : MAFK_K562_MafK_-ab50322-_Stanford
# Downloading results for TF : MAX_K562_Max_HudsonAlpha
# Downloading results for TF : MAX_K562_Max_Stanford
# Downloading results for TF : MAZ_K562_MAZ_-ab85725-_Stanford
# Downloading results for TF : MEF2A_K562_MEF2A_HudsonAlpha
# Downloading results for TF : MXI1_K562_Mxi1_-AF4185-_Stanford
# Downloading results for TF : MYC_K562_c-Myc_Stanford
# Downloading results for TF : MYC_K562_c-Myc_UT-A
# Downloading results for TF : NFE2_K562_NF-E2_Yale
# Downloading results for TF : NFYA_K562_NF-YA_Stanford
# Downloading results for TF : NFYB_K562_NF-YB_Stanford
# Downloading results for TF : NR2F2_K562_NR2F2_-SC-271940-_HudsonAlpha
# Downloading results for TF : NRF1_K562_Nrf1_Stanford
# Downloading results for TF : PHF8_K562_PHF8_-A301-772A-_Broad
# Downloading results for TF : PML_K562_PML_-SC-71910-_HudsonAlpha
# Downloading results for TF : POLR2A_K562_Pol2-4H8_HudsonAlpha
# Downloading results for TF : POLR2A_K562_Pol2-b-_Broad
# Downloading results for TF : POLR2A_K562_Pol2_HudsonAlpha
# Downloading results for TF : POLR2A_K562_Pol2-phosphoS2-_Stanford
# Downloading results for TF : POLR2A_K562_Pol2_Stanford
# Downloading results for TF : POLR2A_K562_Pol2_UT-A
# Downloading results for TF : POLR2A_K562_Pol2_Yale
# Downloading results for TF : RAD21_K562_Rad21_HudsonAlpha
# Downloading results for TF : RBBP5_K562_RBBP5_-A300-109A-_Broad
# Downloading results for TF : RCOR1_K562_COREST_-ab24166-_Stanford
# Downloading results for TF : RCOR1_K562_COREST_-sc-30189-_Stanford
# Downloading results for TF : REST_K562_NRSF_HudsonAlpha
# Downloading results for TF : RFX5_K562_RFX5_-200-401-194-_Stanford
# Downloading results for TF : SAP30_K562_SAP30_-39731-_Broad
# Downloading results for TF : SETDB1_K562_SETDB1_USC
# Downloading results for TF : SIN3AK20_K562_Sin3Ak-20_HudsonAlpha
# Downloading results for TF : SIRT6_K562_SIRT6_Harvard
# Downloading results for TF : SIX5_K562_SIX5_HudsonAlpha
# Downloading results for TF : SMC3_K562_SMC3_-ab9263-_Stanford
# Downloading results for TF : SP1_K562_SP1_HudsonAlpha
# Downloading results for TF : SP2_K562_SP2_-SC-643-_HudsonAlpha
# Downloading results for TF : SPI1_K562_PU_1_HudsonAlpha
# Downloading results for TF : SRF_K562_SRF_HudsonAlpha
# Downloading results for TF : STAT5A_K562_STAT5A_-SC-74442-_HudsonAlpha
# Downloading results for TF : TAF1_K562_TAF1_HudsonAlpha
# Downloading results for TF : TAF7_K562_TAF7_-SC-101167-_HudsonAlpha
# Downloading results for TF : TAL1_K562_TAL1_-SC-12984-_Stanford
# Downloading results for TF : TBL1XR1_K562_TBLR1_-ab24550-_Stanford
# Downloading results for TF : TBL1XR1_K562_TBLR1_-NB600-270-_Stanford
# Downloading results for TF : TBP_K562_TBP_Stanford
# Downloading results for TF : TEAD4_K562_TEAD4_-SC-101184-_HudsonAlpha
# Downloading results for TF : THAP1_K562_THAP1_-SC-98174-_HudsonAlpha
# Downloading results for TF : TRIM28_K562_TRIM28_-SC-81411-_HudsonAlpha
# Downloading results for TF : UBTF_K562_UBF_-sc-13125-_Stanford
# Downloading results for TF : UBTF_K562_UBTF_-SAB1404509-_Stanford
# Downloading results for TF : USF1_K562_USF-1_HudsonAlpha
# Downloading results for TF : USF2_K562_USF2_Stanford
# Downloading results for TF : YY1_K562_YY1_HudsonAlpha
# Downloading results for TF : YY1_K562_YY1_-SC-281-_HudsonAlpha
# Downloading results for TF : ZBTB33_K562_ZBTB33_HudsonAlpha
# Downloading results for TF : ZBTB7A_K562_ZBTB7A_-SC-34508-_HudsonAlpha
# Downloading results for TF : ZNF143_K562_Znf143_-16618-1-AP-_Stanford
# Downloading results for TF : ZNF263_K562_ZNF263_USC
# Downloading results for TF : ZNF274_K562_ZNF274_-M01-_USC
# Downloading results for TF : ZNF274_K562_ZNF274_USC

# %% [markdown]
# ### Collect results from local

# %%
reg_test_metrics_df = {'TFID':[],  'loss':[], 'ACC':[], 'AUROC':[], 'AUPR':[]}
pairwise_test_metrics_df = {'TFID':[], "l1":[], 'loss':[], 'ACC':[], 'AUROC':[], 'AUPR':[]}
nn_test_metrics_df = {'TFID':[], "l1":[], 'loss':[], 'ACC':[], 'AUROC':[], 'AUPR':[]}

for tfid in tfids:
    #print("Collecting results for TF : %s ..."%tfid)
    tfid_dir = os.path.join(RESULTSDIR, tfid)
    
    # get regular conv results 
    reg_test_metrics_df['TFID'].append(tfid)
    reg_dir = os.path.join(tfid_dir, "regular_conv_results")
    reg_path = os.path.join(reg_dir, "test_metrics.csv")
    df=pd.read_csv(reg_path, index_col=[0])
    names = df.Metric.values
    values = df.Value.values
    for name, value in zip(names, values):
        reg_test_metrics_df[name].append(value)
    # get pairwise conv results 
    pairwise_dir = os.path.join(tfid_dir, "pairwise_conv_results")
    for i, l1folder in enumerate(os.listdir(pairwise_dir)):
        pairwise_test_metrics_df['TFID'].append(tfid)
        pairwise_test_metrics_df['l1'].append(str(l1folder).split("=")[-1])
        fname = os.path.join(pairwise_dir, l1folder, "test_metrics.csv")
        df=pd.read_csv(fname, index_col=[0])
        names = df.Metric.values
        values = df.Value.values
        for name, value in zip(names, values):
            pairwise_test_metrics_df[name].append(value)
    
    # get nearest neighbor conv results 
    nn_dir = os.path.join(tfid_dir, "nearest_neighbor_conv_results")
    for i, l1folder in enumerate(os.listdir(nn_dir)):
        nn_test_metrics_df['TFID'].append(tfid)
        nn_test_metrics_df['l1'].append(str(l1folder).split("=")[-1])
        fname = os.path.join(nn_dir, l1folder, "test_metrics.csv")
        df=pd.read_csv(fname, index_col=[0])
        names = df.Metric.values
        values = df.Value.values
        for name, value in zip(names, values):
            nn_test_metrics_df[name].append(value)
    
    
    # get nearest neighbor conv results 
    tfid_nn_dir = os.path.join(tfid_dir, "nearest_neighbor_conv_results")

reg_test_metrics_df = pd.DataFrame(reg_test_metrics_df).sort_values(by='TFID')
pairwise_test_metrics_df = pd.DataFrame(pairwise_test_metrics_df).sort_values(by='TFID')
nn_test_metrics_df = pd.DataFrame(nn_test_metrics_df).sort_values(by='TFID')
highorder_conv_test_metrics = {'pairwise':pairwise_test_metrics_df, 'nearest neighbor':nn_test_metrics_df}
metric_names = list(reg_test_metrics_df.columns[-3:])

# %% [markdown]
# ### plots for NN conv

# %%
model_type = 'nearest neighbor'
test_metrics_df = highorder_conv_test_metrics[model_type]

plt.figure(figsize=(13, 15))
for j,metric_name in enumerate(metric_names):
    plt.subplot(3, 1, j+1)
    best_l1_factor_idx = test_metrics_df.groupby('TFID')[metric_name].idxmax().values
    best_l1_factor = test_metrics_df[['TFID','l1']].iloc[best_l1_factor_idx]
    best_metric = test_metrics_df.groupby('TFID').aggregate({metric_name:'max'})
    best_metric['TFID'] = best_metric.index
    
    best_metric.index = np.arange(len(tfids))
    best_metric = best_metric.iloc[:, ::-1]
    
    best_metric = pd.merge(best_metric, best_l1_factor, on="TFID")
    reg_metric = reg_test_metrics_df[['TFID',metric_name]]
    assert np.all(best_metric.TFID.values==reg_metric.TFID.values) ## make sure comparing the right TF results 
    diff=(best_metric[metric_name]-reg_metric[metric_name]).values
    idx = np.argsort(diff)

    barlist = plt.bar(np.arange(len(diff)), 
            diff[idx], 
            width=0.4, edgecolor='none')
    plt.title("Difference in %s"%metric_name)
    for bar in barlist:
        if bar._height > 0:
            bar.set_color("blue")
        else:
            bar.set_color("red")

# %% [markdown]
# ### plots for pairwise conv

# %%
model_type = 'pairwise'
test_metrics_df = highorder_conv_test_metrics[model_type]

plt.figure(figsize=(13, 15))
for j,metric_name in enumerate(metric_names):
    plt.subplot(3, 1, j+1)
    best_l1_factor_idx = test_metrics_df.groupby('TFID')[metric_name].idxmax().values
    best_l1_factor = test_metrics_df[['TFID','l1']].iloc[best_l1_factor_idx]
    best_metric = test_metrics_df.groupby('TFID').aggregate({metric_name:'max'})
    best_metric['TFID'] = best_metric.index
    best_metric.index = np.arange(len(tfids))
    best_metric = best_metric.iloc[:, ::-1]
    
    best_metric = pd.merge(best_metric, best_l1_factor, on="TFID")
    reg_metric = reg_test_metrics_df[['TFID',metric_name]]
    assert np.all(best_metric.TFID.values==reg_metric.TFID.values) ## make sure comparing the right TF results 
    diff=(best_metric[metric_name]-reg_metric[metric_name]).values
    idx = np.argsort(diff)

    barlist = plt.bar(np.arange(len(diff)), 
            diff[idx], 
            width=0.4, edgecolor='none')
    plt.title("Difference in %s"%metric_name)
    for bar in barlist:
        if bar._height > 0:
            bar.set_color("blue")
        else:
            bar.set_color("red")

# %%
fig, Ax = plt.subplots(7, 2, figsize=(12, 35))
for i, tfid in enumerate(tfids):
    ax = Ax[i]
    
    regular_resultdir = os.path.join(RESULTSDIR, tfid, 'regular_conv_results')
    history_file_path = os.path.join(regular_resultdir, 'history.csv')
    history = pd.read_csv(history_file_path)
    ax[0].plot(history['val_AUROC'])
    #ax[0].plot(history['AUROC'])
    #ax[0].set_ylim(top=0.9)
    ax[0].set_title("Standard conv.", fontsize=15)
    
    pairwise_resultdir = os.path.join(RESULTSDIR, tfid, 'pairwise_conv_results')
    l1_factors = os.listdir(pairwise_resultdir)
    for l1_factor in l1_factors:
        history_file_path = os.path.join(pairwise_resultdir, l1_factor, 'history.csv')
        history = pd.read_csv(history_file_path)
        ax[1].plot(history['val_AUROC'], label=l1_factor)
        #ax[1].plot(history['AUROC'])
    #ax[1].set_ylim(top=0.9)
    ax[1].legend(loc='best')
    ax[1].set_title("Pairwise conv. - various L1 regularizations")
    
    if i == Ax.shape[0] - 1:
        break
